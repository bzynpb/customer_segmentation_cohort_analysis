# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"RFM Customer Segmentation & Cohort Analysis Project"**.
#
# **RFM Analysis** and Customer Segmentation using **K-Means Clustering**.
# - Data Cleaning,
# - Data Visualization
# - Exploratory Data Analysis
# - Cohort and Conduct **Cohort Analysis**.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
import plotly.express as px
sns.set()

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (12,8)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.4f' % x)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Useful Functions

# %%
df0 = pd.read_excel("Online Retail.xlsx")
df = df0.copy()
df
# Out:
#          InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1      536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2      536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3      536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4      536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...            ...        ...                                  ...       ...
# 541904 581587.0000 22613.0000          PACK OF 20 SPACEBOY NAPKINS   12.0000
# 541905 581587.0000 22899.0000         CHILDREN'S APRON DOLLY GIRL     6.0000
# 541906 581587.0000 23254.0000        CHILDRENS CUTLERY DOLLY GIRL     4.0000
# 541907 581587.0000 23255.0000      CHILDRENS CUTLERY CIRCUS PARADE    4.0000
# 541908 581587.0000 22138.0000        BAKING SET 9 PIECE RETROSPOT     3.0000
#
# ...

# %% [markdown]
# ### Explore Data

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB

# %%
print('{:,} rows; {:,} columns'
      .format(df.shape[0], df.shape[1]))
print('{:,} transactions don\'t have a customer id'
      .format(df[df.CustomerID.isnull()].shape[0]))
print('Transactions timeframe from {} to {}'.format(df['InvoiceDate'].min(),
                                    df['InvoiceDate'].max()))
# Out:
# 541,909 rows; 8 columns
# 135,080 transactions don't have a customer id
# Transactions timeframe from 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 33.1+ MB

# %%
df.describe().T
# Out:
#                 count   mean      std         min    25%    50%     75%  \
# Quantity  541909.0000 9.5522 218.0812 -80995.0000 1.0000 3.0000 10.0000
# UnitPrice 541909.0000 4.6111  96.7599 -11062.0600 1.2500 2.0800  4.1300
#
#                  max
# Quantity  80995.0000
# UnitPrice 38970.0000

# %%
df.describe(include="all").T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_eaec5_row0_col0, #T_eaec5_row1_col0, #T_eaec5_row3_col0, #T_eaec5_row4_col0, #T_eaec5_row5_col0, #T_eaec5_row6_col6, #T_eaec5_row6_col7, #T_eaec5_row6_col10, #T_eaec5_row7_col0 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_eaec5_row0_col6, #T_eaec5_row0_col7, #T_eaec5_row0_col10, #T_eaec5_row1_col6, #T_eaec5_row1_col7, #T_eaec5_row1_col10, #T_eaec5_row2_col6, #T_eaec5_row2_col7, #T_eaec5_row2_col10, #T_eaec5_row4_col6, #T_eaec5_row4_col7, #T_eaec5_row4_col10, #T_eaec5_row7_col6, #T_eaec5_row7_col7, #T_eaec5_row7_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_eaec5_row2_col0 {
#   background-color: #4c006b;
#   color: #f1f1f1;
# }
# #T_eaec5_row3_col6, #T_eaec5_row3_col10, #T_eaec5_row5_col6, #T_eaec5_row5_col7, #T_eaec5_row5_col10, #T_eaec5_row6_col0 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_eaec5_row3_col7 {
#   background-color: #fee9e6;
#   color: #000000;
# }
# </style>
# <table id="T_eaec5">
# ...

# %%
df.isnull().sum()
# we have missing values
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print('Dublicate rows: {}'.format(df.duplicated().sum()))

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4373
# Country           38
# dtype: int64

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1       536365.0   71053.0                  WHITE METAL LANTERN    6.0000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS   12.0000
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL     6.0000
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL     4.0000
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE    4.0000
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT     3.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4373
# Country           38
# dtype: int64

# %% [markdown]
# ### InvoiceNo

# %%
df['InvoiceNo'].value_counts(dropna=False)
# Out:
# 573585.0    1114
# 581219.0     749
# 581492.0     731
# 580729.0     721
# 558475.0     705
#             ...
# 554023.0       1
# 554022.0       1
# 554021.0       1
# 554020.0       1
# C558901        1
# Name: InvoiceNo, Length: 25900, dtype: int64

# %%
# Invoice that has most item in it
df[df['InvoiceNo'].astype('str')=='573585.0']
# Out:
#          InvoiceNo     StockCode                         Description  \
# 430237 573585.0000    11001.0000         ASSTD DESIGN RACING CAR PEN
# 430238 573585.0000    15036.0000           ASSORTED COLOURS SILK FAN
# 430239 573585.0000    15039.0000                      SANDALWOOD FAN
# 430240 573585.0000       15056BL             EDWARDIAN PARASOL BLACK
# 430241 573585.0000        15056N           EDWARDIAN PARASOL NATURAL
# ...            ...           ...                                 ...
# 431346 573585.0000        90209C         PINK ENAMEL+GLASS HAIR COMB
# 431347 573585.0000        90214S           LETTER "S" BLING KEY RING
# 431348 573585.0000           DOT                      DOTCOM POSTAGE
# 431349 573585.0000  gift_0001_20  Dotcomgiftshop Gift Voucher œ20.00
# 431350 573585.0000    23539.0000             WALL ART LOVES' SECRET
#
#         Quantity         InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['InvoiceNo'].str[0]
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 541904    5
# 541905    5
# 541906    5
# 541907    5
# 541908    5
# Name: InvoiceNo, Length: 541909, dtype: object

# %%
df[df['InvoiceNo'].astype('str').str[0]=='C']
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount   -1.0000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS   -1.0000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE   -12.0000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES   -24.0000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES   -24.0000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL  -11.0000
# 541541   C581499         M                            Manual   -1.0000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE   -5.0000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER   -1.0000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT   -5.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
df['InvoiceNo'].str[0].value_counts()
# Out:
# 5    532618
# C      9288
# A         3
# Name: InvoiceNo, dtype: int64

# %%
df[df['InvoiceNo'].str[0]=='A']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt    1.0000 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt    1.0000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt    1.0000 2011-08-12 14:52:00
#
#          UnitPrice CustomerID         Country
# 299982  11062.0600        nan  United Kingdom
# 299983 -11062.0600        nan  United Kingdom
# 299984 -11062.0600        nan  United Kingdom

# %%
df[df['StockCode']=='B']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt    1.0000 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt    1.0000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt    1.0000 2011-08-12 14:52:00
#
#          UnitPrice CustomerID         Country
# 299982  11062.0600        nan  United Kingdom
# 299983 -11062.0600        nan  United Kingdom
# 299984 -11062.0600        nan  United Kingdom

# %% [markdown]
# ### Description

# %%
df['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: Description, Length: 4223, dtype: int64

# %%
df.groupby(["StockCode"])["Quantity"].sum().sort_values(ascending=False).head()
# Out:
# StockCode
# 23843.0   80995.0000
# 23166.0   78033.0000
# 22197.0   56898.0000
# 84077.0   54951.0000
# 85099B    48371.0000
# Name: Quantity, dtype: float64

# %%
print('Dublicate rows: {}'.format(df.duplicated().sum()))
df.drop_duplicates(inplace=True)
# df.to_excel('df_clean.xlsx')
# Out:
# Dublicate rows: 5268

# %% [markdown]
# ## Top-selling product

# %%
df[df['StockCode']=='23843.0']
# but this order is cancelled!
# Out:
#        InvoiceNo StockCode                  Description    Quantity  \
# 540421  581483.0   23843.0  PAPER CRAFT , LITTLE BIRDIE  80995.0000
# 540422   C581484   23843.0  PAPER CRAFT , LITTLE BIRDIE -80995.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 540421 2011-12-09 09:15:00     2.0800    16446.0  United Kingdom
# 540422 2011-12-09 09:27:00     2.0800    16446.0  United Kingdom

# %%
df[df['StockCode']=='23166.0']
# Out:
#        InvoiceNo StockCode                     Description   Quantity  \
# 61619   541431.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR 74215.0000
# 186770  552882.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR    96.0000
# 187196  552953.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     4.0000
# 187718  553005.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     5.0000
# 187868  553009.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     3.0000
# ...          ...       ...                             ...        ...
# 533742  581108.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     2.0000
# 536248  581219.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     1.0000
# 539776  581439.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     2.0000
# 540301  581476.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR    48.0000
# 541101  581492.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR     2.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country year_month  \
# ...

# %% [markdown]
# ## 2nd best selling product

# %%
df[df['StockCode']=='22197.0']
# Out:
#        InvoiceNo StockCode           Description  Quantity  \
# 221     536390.0   22197.0  SMALL POPCORN HOLDER  100.0000
# 393     536404.0   22197.0  SMALL POPCORN HOLDER   36.0000
# 532     536409.0   22197.0  SMALL POPCORN HOLDER    2.0000
# 610     536412.0   22197.0  SMALL POPCORN HOLDER    5.0000
# 804     536464.0   22197.0  SMALL POPCORN HOLDER    5.0000
# ...          ...       ...                   ...       ...
# 540321  581476.0   22197.0        POPCORN HOLDER  100.0000
# 540785  581492.0   22197.0        POPCORN HOLDER   34.0000
# 541285  581497.0   22197.0        POPCORN HOLDER   68.0000
# 541678  581538.0   22197.0        POPCORN HOLDER    4.0000
# 541825  581579.0   22197.0        POPCORN HOLDER   24.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country year_month  \
# 221    2010-12-01 10:19:00     0.7200    17511.0  United Kingdom    2010-12
# 393    2010-12-01 11:29:00     0.8500    16218.0  United Kingdom    2010-12
# ...

# %% [markdown]
# ## 3rd best selling product

# %%
df[df['StockCode']=='84077.0']
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 3259    536615.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS   48.0000
# 3297    536618.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS   48.0000
# 4945    536830.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS 2880.0000
# 5047    536839.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS  288.0000
# 5278    536856.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS   48.0000
# ...          ...       ...                                ...       ...
# 534797  581171.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS   48.0000
# 538240  581403.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS   48.0000
# 538846  581419.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS  288.0000
# 540377  581478.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS   48.0000
# 540548  581492.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS    1.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country year_month  \
# ...

# %% [markdown]
# ### Quantity

# %%
df[df.Quantity<0]

# %%
(df[(df.Quantity<0)]['Country'].value_counts())/df['Country'].value_counts(sort=True)
# Out:
# Australia              0.0588
# Austria                0.0075
# Bahrain                0.0526
# Belgium                0.0184
# Brazil                    NaN
# Canada                    NaN
# Channel Islands        0.0132
# Cyprus                 0.0129
# Czech Republic         0.1667
# Denmark                0.0231
# EIRE                   0.0368
# European Community     0.0164
# Finland                0.0144
# France                 0.0174
# Germany                0.0477
# Greece                 0.0068
# Hong Kong              0.0139
# Iceland                   NaN
# Israel                 0.0067
# Italy                  0.0560
# Japan                  0.1034
# Lebanon                   NaN
# Lithuania                 NaN
# Malta                  0.1181
# Netherlands            0.0034
# Norway                 0.0129
# Poland                 0.0323
# Portugal               0.0118
# RSA                       NaN
# Saudi Arabia           0.1000
# Singapore              0.0306
# ...

# %% [markdown]
# ### InvoiceDate

# %%
df['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 536641, dtype: datetime64[ns]

# %%
df['year_month'] = df['InvoiceDate'].astype('str').str[:7]
df0['year_month'] = df0['InvoiceDate'].astype('str').str[:7]
df['year_month']
# Out:
# 0         2010-12
# 1         2010-12
# 2         2010-12
# 3         2010-12
# 4         2010-12
#            ...
# 541904    2011-12
# 541905    2011-12
# 541906    2011-12
# 541907    2011-12
# 541908    2011-12
# Name: year_month, Length: 541909, dtype: object

# %% [markdown]
# ### UnitPrice

# %%
df[df['UnitPrice']<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt    1.0000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt    1.0000 2011-08-12 14:52:00
#
#          UnitPrice CustomerID         Country year_month
# 299983 -11062.0600        nan  United Kingdom    2011-08
# 299984 -11062.0600        nan  United Kingdom    2011-08

# %%
# most expences product - minus quantity --> probably returned items
df[df['UnitPrice']==df['UnitPrice'].max()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 222681   C556445         M      Manual   -1.0000 2011-06-10 15:31:00
#
#         UnitPrice  CustomerID         Country
# 222681 38970.0000  15098.0000  United Kingdom

# %%
df[df['StockCode']=="M"]
# Out:
#          InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2239   536569.0000         M      Manual    1.0000 2010-12-01 15:35:00
# 2250   536569.0000         M      Manual    1.0000 2010-12-01 15:35:00
# 5684   536865.0000         M      Manual    1.0000 2010-12-03 11:28:00
# 6798   536981.0000         M      Manual    2.0000 2010-12-03 14:26:00
# 7976   537077.0000         M      Manual   12.0000 2010-12-05 11:59:00
# ...            ...       ...         ...       ...                 ...
# 531432 580956.0000         M      Manual    4.0000 2011-12-06 14:23:00
# 533082     C581009         M      Manual   -1.0000 2011-12-07 09:15:00
# 534308     C581145         M      Manual   -1.0000 2011-12-07 13:48:00
# 538321 581405.0000         M      Manual    3.0000 2011-12-08 13:50:00
# 541541     C581499         M      Manual   -1.0000 2011-12-09 10:28:00
#
#         UnitPrice  CustomerID         Country
# 2239       1.2500  16274.0000  United Kingdom
# ...

# %% [markdown]
# ### CustomerID

# %% [markdown]
# ### Country

# %%
df['Country'].value_counts(dropna=False)
# Out:
# United Kingdom          490300
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     294
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df["Quantity"].corr(df["UnitPrice"])
# Out:
# -0.001241039673356979

# %%
df[['InvoiceNo','Quantity','UnitPrice']].value_counts()
# Out:
# InvoiceNo  Quantity  UnitPrice
# 573585.0   1.0000    2.4600       71
# 580367.0   1.0000    2.4600       59
# 580730.0   1.0000    2.4600       57
# 580729.0   1.0000    4.1300       55
# 579512.0   1.0000    2.4600       54
#                                   ..
# 556092.0   3.0000    1.6300        1
#                      3.2900        1
#                      6.6300        1
#            4.0000    4.1300        1
# C581569    -1.0000   1.2500        1
# Length: 304588, dtype: int64

# %%
df[['InvoiceNo','Quantity','UnitPrice']].describe().T
# Out:
#                 count   mean      std         min    25%    50%     75%  \
# Quantity  536641.0000 9.6200 219.1302 -80995.0000 1.0000 3.0000 10.0000
# UnitPrice 536641.0000 4.6327  97.2331 -11062.0600 1.2500 2.0800  4.1300
#
#                  max
# Quantity  80995.0000
# UnitPrice 38970.0000

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df.loc[df['UnitPrice']<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt    1.0000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt    1.0000 2011-08-12 14:52:00
#
#          UnitPrice CustomerID         Country year_month
# 299983 -11062.0600        nan  United Kingdom    2011-08
# 299984 -11062.0600        nan  United Kingdom    2011-08

# %%
# df[df['Quantity']<0] # 10624 rows × 9 columns
df[df['InvoiceNo'].str[0]=='C'] # 9288 rows
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount   -1.0000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS   -1.0000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE   -12.0000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES   -24.0000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES   -24.0000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL  -11.0000
# 541541   C581499         M                            Manual   -1.0000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE   -5.0000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER   -1.0000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT   -5.0000
#
#                InvoiceDate  UnitPrice CustomerID         Country year_month
# ...

# %%
df.loc[(df['Quantity']<0)][df['InvoiceNo'].str[0]!='C']
# Out:
#        InvoiceNo StockCode Description   Quantity         InvoiceDate  \
# 2406    536589.0   21777.0         NaN   -10.0000 2010-12-01 16:50:00
# 4347    536764.0    84952C         NaN   -38.0000 2010-12-02 14:42:00
# 7188    536996.0   22712.0         NaN   -20.0000 2010-12-03 15:30:00
# 7189    536997.0   22028.0         NaN   -20.0000 2010-12-03 15:30:00
# 7190    536998.0   85067.0         NaN    -6.0000 2010-12-03 15:30:00
# ...          ...       ...         ...        ...                 ...
# 535333  581210.0   23395.0       check   -26.0000 2011-12-07 18:36:00
# 535335  581212.0   22578.0        lost -1050.0000 2011-12-07 18:38:00
# 535336  581213.0   22576.0       check   -30.0000 2011-12-07 18:38:00
# 536908  581226.0   23090.0     missing  -338.0000 2011-12-08 09:56:00
# 538919  581422.0   23169.0     smashed  -235.0000 2011-12-08 15:24:00
#
#         UnitPrice CustomerID         Country year_month
# 2406       0.0000        nan  United Kingdom    2010-12
# ...

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
df["Cancelled"] = df.InvoiceNo.str.startswith("C", na=False)

df[df.Cancelled & (df.Quantity>0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, year_month, Cancelled]
# Index: []

# %%
num_cancelled = pd.Series(df.InvoiceNo.unique()).str.startswith("C", na=False).sum()

num_invoice = len(df.InvoiceNo.unique())

num_invoice
# Out:
# 25900

# %%
print( f"Cancelled num of orders: {num_cancelled} , \nCancelation ratio:{num_cancelled/num_invoice:.2}" )
# Out:
# Cancelled num of orders: 3836 ,
# Cancelation ratio:0.15

# %%
df[(~df.Cancelled) & (df.Quantity<0)].UnitPrice.value_counts()
# Out:
# 0.0000    1336
# Name: UnitPrice, dtype: int64

# %%
# df.groupby(df['InvoiceNo'].str[0]=='C')[['year_month']].sum()

# %% [markdown]
# #### 3836 or about 15% of the orders were cancelled. Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df.loc[(df['Quantity']<0)][df['InvoiceNo'].str[0]!='C']
# Out:
#        InvoiceNo StockCode Description   Quantity         InvoiceDate  \
# 2406    536589.0   21777.0         NaN   -10.0000 2010-12-01 16:50:00
# 4347    536764.0    84952C         NaN   -38.0000 2010-12-02 14:42:00
# 7188    536996.0   22712.0         NaN   -20.0000 2010-12-03 15:30:00
# 7189    536997.0   22028.0         NaN   -20.0000 2010-12-03 15:30:00
# 7190    536998.0   85067.0         NaN    -6.0000 2010-12-03 15:30:00
# ...          ...       ...         ...        ...                 ...
# 535333  581210.0   23395.0       check   -26.0000 2011-12-07 18:36:00
# 535335  581212.0   22578.0        lost -1050.0000 2011-12-07 18:38:00
# 535336  581213.0   22576.0       check   -30.0000 2011-12-07 18:38:00
# 536908  581226.0   23090.0     missing  -338.0000 2011-12-08 09:56:00
# 538919  581422.0   23169.0     smashed  -235.0000 2011-12-08 15:24:00
#
#         UnitPrice CustomerID         Country year_month  Cancelled
# ...

# %% [markdown]
# ### iii. Handling Missing Values

# %%
df = df[(df.Quantity > 0) & (df.UnitPrice > 0)]
# dropping cancelled orders

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
df['CustomerID'].dropna(axis=0,inplace=True)

# %%
df
# Out:
#          InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1      536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2      536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3      536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4      536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...            ...        ...                                  ...       ...
# 541904 581587.0000 22613.0000          PACK OF 20 SPACEBOY NAPKINS   12.0000
# 541905 581587.0000 22899.0000         CHILDREN'S APRON DOLLY GIRL     6.0000
# 541906 581587.0000 23254.0000        CHILDRENS CUTLERY DOLLY GIRL     4.0000
# 541907 581587.0000 23255.0000      CHILDRENS CUTLERY CIRCUS PARADE    4.0000
# 541908 581587.0000 22138.0000        BAKING SET 9 PIECE RETROSPOT     3.0000
#
# ...

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby(['CustomerID','InvoiceNo'])['Quantity'].nunique().sort_values(ascending=False)
# Out:
# CustomerID  InvoiceNo
# 14088.0000  555400.0000    35
#             578305.0000    32
# 14096.0000  579196.0000    31
# 14088.0000  571281.0000    30
# 14646.0000  563076.0000    29
#                            ..
# 13709.0000  580758.0000     1
# 15649.0000  537461.0000     1
# 13715.0000  538501.0000     1
# 15640.0000  562879.0000     1
# 12346.0000  541431.0000     1
# Name: Quantity, Length: 18532, dtype: int64

# %%
df.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 12748.0000    209
# 14911.0000    201
# 17841.0000    124
# 13089.0000     97
# 14606.0000     93
#              ...
# 15314.0000      1
# 15313.0000      1
# 15308.0000      1
# 15307.0000      1
# 15300.0000      1
# Name: InvoiceNo, Length: 4338, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.groupby(["InvoiceNo", 'StockCode'])['Quantity'].mean()
# Out:
# InvoiceNo  StockCode
# 536365.0   21730.0     6.0000
#            22752.0     2.0000
#            71053.0     6.0000
#            84029E      6.0000
#            84029G      6.0000
#                         ...
# 581587.0   22899.0     6.0000
#            23254.0     4.0000
#            23255.0     4.0000
#            23256.0     4.0000
# A563185    B           1.0000
# Name: Quantity, Length: 519602, dtype: float64

# %%
#  average number of unqiue items per order
df.groupby(["InvoiceNo","StockCode"])["Quantity"].nunique().mean()
# Out:
# 1.009992263309225

# %% [markdown]
# ---

# %%
df.groupby(["CustomerID","StockCode"])["Quantity"].mean()
# Out:
# CustomerID  StockCode
# 12346.0000  23166.0     74215.0000
# 12347.0000  16008.0        24.0000
#             17021.0        36.0000
#             20665.0         6.0000
#             20719.0        10.0000
#                            ...
# 18287.0000  72351B         24.0000
#             84507C          6.0000
#             85039A         48.0000
#             85039B         40.0000
#             85040A         24.0000
# Name: Quantity, Length: 266792, dtype: float64

# %%
#  average number of unqiue items per customer
df.groupby(["CustomerID","StockCode"])["Quantity"].nunique().mean()
# Out:
# 1.1940125640948753

# %% [markdown]
# ---

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby(['CustomerID', 'InvoiceNo', 'StockCode'])['Quantity'].sum()
# Out:
# CustomerID  InvoiceNo    StockCode
# 12346.0000  541431.0000  23166.0     74215.0000
# 12347.0000  537626.0000  20780.0        12.0000
#                          20782.0         6.0000
#                          21064.0         6.0000
#                          21171.0        12.0000
#                                         ...
# 18287.0000  570715.0000  85039A         48.0000
#                          85039B         48.0000
#             573167.0000  21014.0        24.0000
#                          21824.0        48.0000
#                          23264.0        36.0000
# Name: Quantity, Length: 387841, dtype: float64

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df['revenue'] = df['UnitPrice']*df['Quantity']
# df0['revenue'] = df0['UnitPrice']*df0['Quantity']
df
# Out:
#          InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1      536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2      536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3      536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4      536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...            ...        ...                                  ...       ...
# 541904 581587.0000 22613.0000          PACK OF 20 SPACEBOY NAPKINS   12.0000
# 541905 581587.0000 22899.0000         CHILDREN'S APRON DOLLY GIRL     6.0000
# 541906 581587.0000 23254.0000        CHILDRENS CUTLERY DOLLY GIRL     4.0000
# 541907 581587.0000 23255.0000      CHILDRENS CUTLERY CIRCUS PARADE    4.0000
# 541908 581587.0000 22138.0000        BAKING SET 9 PIECE RETROSPOT     3.0000
#
# ...

# %%
df.groupby('Country')[["revenue"]].sum().sort_values(by="revenue", ascending=False)
# Out:
#                           revenue
# Country
# United Kingdom       9025222.0840
# Netherlands           285446.3400
# EIRE                  283453.9600
# Germany               228867.1400
# France                209715.1100
# Australia             138521.3100
# Spain                  61577.1100
# Switzerland            57089.9000
# Belgium                41196.3400
# Sweden                 38378.3300
# Japan                  37416.3700
# Norway                 36165.4400
# Portugal               33747.1000
# Finland                22546.0800
# Singapore              21279.2900
# Channel Islands        20450.4400
# Denmark                18955.3400
# Italy                  17483.2400
# Hong Kong              15691.8000
# Cyprus                 13590.3800
# Austria                10198.6800
# Israel                  8135.2600
# Poland                  7334.6500
# Greece                  4760.5200
# Unspecified             4749.7900
# Iceland                 4310.0000
# ...

# %%
df[df['Country']=="United Kingdom"].groupby(['year_month'])['revenue'].sum()
# after removing customerID==NaN and cancelled orders
# Out:
# year_month
# 2010-12    748268.9800
# 2011-01    561289.9800
# 2011-02    430027.9500
# 2011-03    586230.2800
# 2011-04    476517.7610
# 2011-05    639314.3600
# 2011-06    619510.6700
# 2011-07    601994.8410
# 2011-08    608047.4800
# 2011-09    897076.4720
# 2011-10    938975.0100
# 2011-11   1325346.2100
# 2011-12    592622.0900
# Name: revenue, dtype: float64

# %% [markdown]
# 2. Visualize number of customer per country

# %%
cust_per_contry = df.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False)
cust_per_contry
# Out:
# Country
# United Kingdom          3920
# Germany                   94
# France                    87
# Spain                     30
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     14
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Channel Islands            9
# Denmark                    9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Unspecified                4
# Greece                     4
# EIRE                       3
# Israel                     3
# Malta                      2
# United Arab Emirates       2
# Bahrain                    2
# Lithuania                  1
# Czech Republic             1
# Lebanon                    1
# ...

# %% [markdown]
# 3. Visualize total cost per country

# %%
df.groupby('Country')['revenue'].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          4757
# EIRE                     574
# Germany                  500
# France                   481
# Netherlands              425
# Australia                346
# Spain                    324
# Switzerland              304
# Portugal                 241
# Norway                   217
# Belgium                  181
# Cyprus                   179
# Finland                  156
# Sweden                   152
# Italy                    142
# Channel Islands          141
# Japan                    139
# Israel                   134
# Unspecified              125
# Denmark                  121
# Austria                  102
# Hong Kong                102
# Poland                    99
# Singapore                 98
# USA                       73
# Greece                    58
# Canada                    57
# Iceland                   56
# Malta                     50
# United Arab Emirates      38
# Lebanon                   33
# ...

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk = df[df.Country == 'United Kingdom']
df_uk
# Out:
#          InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1      536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2      536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3      536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4      536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...            ...        ...                                  ...       ...
# 541889 581585.0000 22466.0000       FAIRY TALE COTTAGE NIGHT LIGHT   12.0000
# 541890 581586.0000 22061.0000  LARGE CAKE STAND  HANGING STRAWBERY    8.0000
# 541891 581586.0000 23275.0000     SET OF 3 HANGING OWLS OLLIE BEAK   24.0000
# 541892 581586.0000 21217.0000        RED RETROSPOT ROUND CAKE TINS   24.0000
# 541893 581586.0000 20685.0000                DOORMAT RED RETROSPOT   10.0000
#
# ...

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby(["StockCode"])["Quantity"].sum().sort_values(ascending=False)
# Out:
# StockCode
# 23843.0   80995.0000
# 23166.0   77036.0000
# 22197.0   53343.0000
# 84077.0   49526.0000
# 85099B    44264.0000
#              ...
# 84031b        1.0000
# 84031a        1.0000
# 82613a        1.0000
# 90126A        1.0000
# m             1.0000
# Name: Quantity, Length: 3916, dtype: float64

# %%
df[df['StockCode']=='85099B']
# Out:
#          InvoiceNo StockCode              Description  Quantity  \
# 177    536386.0000    85099B  JUMBO BAG RED RETROSPOT  100.0000
# 234    536390.0000    85099B  JUMBO BAG RED RETROSPOT  100.0000
# 533    536409.0000    85099B  JUMBO BAG RED RETROSPOT    2.0000
# 790    536464.0000    85099B  JUMBO BAG RED RETROSPOT    1.0000
# 1069   536522.0000    85099B  JUMBO BAG RED RETROSPOT    1.0000
# ...            ...       ...                      ...       ...
# 538603 581412.0000    85099B  JUMBO BAG RED RETROSPOT    3.0000
# 538913 581421.0000    85099B  JUMBO BAG RED RETROSPOT    9.0000
# 539338 581439.0000    85099B  JUMBO BAG RED RETROSPOT    1.0000
# 540434 581486.0000    85099B  JUMBO BAG RED RETROSPOT   10.0000
# 541536 581498.0000    85099B  JUMBO BAG RED RETROSPOT    5.0000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  revenue  \
# 177    2010-12-01 09:57:00     1.6500  16029.0000  United Kingdom 165.0000
# ...

# %%
df_uk['InvoiceDate'].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
df_uk['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
df_uk['StockCode'].value_counts()
# Out:
# 85123A     2169
# 85099B     1957
# 22423.0    1710
# 47566.0    1614
# 20725.0    1421
#            ...
# 44265.0       1
# 84795C        1
# 17028J        1
# 84201C        1
# 23843.0       1
# Name: StockCode, Length: 3916, dtype: int64

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# ## 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#     InvoiceNo  StockCode                          Description  Quantity  \
# 0 536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1 536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2 536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3 536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4 536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  revenue  \
# 0 2010-12-01 08:26:00     2.5500  17850.0000  United Kingdom  15.3000
# 1 2010-12-01 08:26:00     3.3900  17850.0000  United Kingdom  20.3400
# 2 2010-12-01 08:26:00     2.7500  17850.0000  United Kingdom  22.0000
# 3 2010-12-01 08:26:00     3.3900  17850.0000  United Kingdom  20.3400
# 4 2010-12-01 08:26:00     3.3900  17850.0000  United Kingdom  20.3400
#
#   year_month
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %%
recent_date = df_uk['InvoiceDate'].max()
recent_date = recent_date.date()
recent_date #en son yapilan asliveris
# Out:
# datetime.date(2011, 12, 9)

# %%
recent_date

# %%
## List dublicate values
def list_duplicates(seq):
    seen = set()
    seen_add = seen.add
  # adds all elements it doesn't know yet to seen and all other to seen_twice
    seen_twice = set( x for x in seq if x in seen or seen_add(x) )
  # turn the set into a list (as requested)
    return list( seen_twice )

# %%
df_uk_group = df_uk.groupby('CustomerID')['InvoiceDate'].apply(list).reset_index() 
df_uk_group['first_order'] = df_uk_group['InvoiceDate'].str[0] # first order
df_uk_group['last_2.'] = df_uk_group['InvoiceDate'].str[-2] # last 2.
df_uk_group['last_order'] = df_uk_group['InvoiceDate'].str[-1] # last order 

df_uk_group
# Out:
#       CustomerID                                        InvoiceDate  \
# 0     12346.0000                              [2011-01-18 10:01:00]
# 1     12747.0000  [2010-12-05 15:38:00, 2010-12-05 15:38:00, 201...
# 2     12748.0000  [2010-12-01 12:48:00, 2010-12-02 11:46:00, 201...
# 3     12749.0000  [2011-05-10 15:25:00, 2011-05-10 15:25:00, 201...
# 4     12820.0000  [2011-01-17 12:34:00, 2011-01-17 12:34:00, 201...
# ...          ...                                                ...
# 3915  18280.0000  [2011-03-07 09:52:00, 2011-03-07 09:52:00, 201...
# 3916  18281.0000  [2011-06-12 10:53:00, 2011-06-12 10:53:00, 201...
# 3917  18282.0000  [2011-08-05 13:35:00, 2011-08-05 13:35:00, 201...
# 3918  18283.0000  [2011-01-06 14:14:00, 2011-01-06 14:14:00, 201...
# 3919  18287.0000  [2011-05-22 10:39:00, 2011-05-22 10:39:00, 201...
#
#               first_order              last_2.           last_order
# 0     2011-01-18 10:01:00                  NaN  2011-01-18 10:01:00
# ...

# %%
#Convert ORDERDATE to datetime format.
df_uk['InvoiceDate'] = pd.to_datetime(df_uk['InvoiceDate'])

# %%
NOW = dt.datetime(2011,12,9)

# %%
# RFM Table
RFM_table = df_uk.groupby('CustomerID').agg({'InvoiceDate': lambda x: (NOW - x.max()).days, # Recency
                                                'InvoiceNo': lambda x: len(x.unique()), # Frequency
                                                'revenue': lambda x: x.sum()})    # Monetary 

RFM_table['InvoiceDate'] = RFM_table['InvoiceDate'].astype(int)

RFM_table.rename(columns={'InvoiceDate': 'recency', 
                         'InvoiceNo': 'frequency',
                         'revenue': 'monetary_value'}, inplace=True)
RFM_table.head()
# Out:
#             recency  frequency  monetary_value
# CustomerID
# 12346.0000      324          1      77183.6000
# 12747.0000        1         11       4196.0100
# 12748.0000       -1        209      33719.7300
# 12749.0000        2          5       4090.8800
# 12820.0000        2          4        942.3400

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
now = dt.datetime(2011,12,10)

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uk['date'] = df_uk['InvoiceDate'].dt.date #dt.date yazarak sadece yil ay gun alinir.

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_uk.groupby('CustomerID')['date'].max()  #en son alisverisi bulmamiz icin max date bulmamiz gerek
 #herbir customerin son alisverisi
# Out:
# CustomerID
# 12346.0000    2011-01-18
# 12747.0000    2011-12-07
# 12748.0000    2011-12-09
# 12749.0000    2011-12-06
# 12820.0000    2011-12-06
#                  ...
# 18280.0000    2011-03-07
# 18281.0000    2011-06-12
# 18282.0000    2011-12-02
# 18283.0000    2011-12-06
# 18287.0000    2011-10-28
# Name: date, Length: 3920, dtype: object

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df_uk_group['recency'] = df_uk_group["last_order"].apply(lambda x: (now- pd.to_datetime(x)).days)
#simdiki zamandan son alisveris yapilan zamani cikartirsak ,en son
## son iki siparis arasinda gecen zaman
df_uk_group[['CustomerID','recency']]
# Out:
#       CustomerID  recency
# 0     12346.0000      325
# 1     12747.0000        2
# 2     12748.0000        0
# 3     12749.0000        3
# 4     12820.0000        3
# ...          ...      ...
# 3915  18280.0000      277
# 3916  18281.0000      180
# 3917  18282.0000        7
# 3918  18283.0000        3
# 3919  18287.0000       42
#
# [3920 rows x 2 columns]

# %%
df_uk_group
# Out:
#       CustomerID                                        InvoiceDate  \
# 0     12346.0000                              [2011-01-18 10:01:00]
# 1     12747.0000  [2010-12-05 15:38:00, 2010-12-05 15:38:00, 201...
# 2     12748.0000  [2010-12-01 12:48:00, 2010-12-02 11:46:00, 201...
# 3     12749.0000  [2011-05-10 15:25:00, 2011-05-10 15:25:00, 201...
# 4     12820.0000  [2011-01-17 12:34:00, 2011-01-17 12:34:00, 201...
# ...          ...                                                ...
# 3915  18280.0000  [2011-03-07 09:52:00, 2011-03-07 09:52:00, 201...
# 3916  18281.0000  [2011-06-12 10:53:00, 2011-06-12 10:53:00, 201...
# 3917  18282.0000  [2011-08-05 13:35:00, 2011-08-05 13:35:00, 201...
# 3918  18283.0000  [2011-01-06 14:14:00, 2011-01-06 14:14:00, 201...
# 3919  18287.0000  [2011-05-22 10:39:00, 2011-05-22 10:39:00, 201...
#
#               first_order              last_2.           last_order  frequency
# ...

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_uk.drop('date', axis = 1, inplace =True)

# %% [markdown]
# 6. Plot RFM distributions

# %%
sns.histplot(data=RFM_table, x='recency');

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk.duplicated().sum()
# Out:
# 0

# %%
df_uk_copy = df_uk.copy()
df_uk_copy
# Out:
#          InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1      536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2      536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3      536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4      536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...            ...        ...                                  ...       ...
# 541889 581585.0000 22466.0000       FAIRY TALE COTTAGE NIGHT LIGHT   12.0000
# 541890 581586.0000 22061.0000  LARGE CAKE STAND  HANGING STRAWBERY    8.0000
# 541891 581586.0000 23275.0000     SET OF 3 HANGING OWLS OLLIE BEAK   24.0000
# 541892 581586.0000 21217.0000        RED RETROSPOT ROUND CAKE TINS   24.0000
# 541893 581586.0000 20685.0000                DOORMAT RED RETROSPOT   10.0000
#
# ...

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_uk_group['frequency']= df_uk.groupby('CustomerID')[["InvoiceNo"]].nunique().reset_index()['InvoiceNo']
df_uk_group
# Out:
#       CustomerID                                        InvoiceDate  \
# 0     12346.0000                              [2011-01-18 10:01:00]
# 1     12747.0000  [2010-12-05 15:38:00, 2010-12-05 15:38:00, 201...
# 2     12748.0000  [2010-12-01 12:48:00, 2010-12-02 11:46:00, 201...
# 3     12749.0000  [2011-05-10 15:25:00, 2011-05-10 15:25:00, 201...
# 4     12820.0000  [2011-01-17 12:34:00, 2011-01-17 12:34:00, 201...
# ...          ...                                                ...
# 3915  18280.0000  [2011-03-07 09:52:00, 2011-03-07 09:52:00, 201...
# 3916  18281.0000  [2011-06-12 10:53:00, 2011-06-12 10:53:00, 201...
# 3917  18282.0000  [2011-08-05 13:35:00, 2011-08-05 13:35:00, 201...
# 3918  18283.0000  [2011-01-06 14:14:00, 2011-01-06 14:14:00, 201...
# 3919  18287.0000  [2011-05-22 10:39:00, 2011-05-22 10:39:00, 201...
#
#               first_order              last_2.           last_order  recency  \
# ...

# %% [markdown]
# 3. Plot RFM distributions

# %%
plt.figure(figsize=(16,9))
sns.distplot(df_uk_group['frequency'], bins=50);

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_uk_group['monetary']= df_uk.groupby('CustomerID')[["revenue"]].sum().reset_index()['revenue']
df_uk_group
# Out:
#       CustomerID                                        InvoiceDate  \
# 0     12346.0000                              [2011-01-18 10:01:00]
# 1     12747.0000  [2010-12-05 15:38:00, 2010-12-05 15:38:00, 201...
# 2     12748.0000  [2010-12-01 12:48:00, 2010-12-02 11:46:00, 201...
# 3     12749.0000  [2011-05-10 15:25:00, 2011-05-10 15:25:00, 201...
# 4     12820.0000  [2011-01-17 12:34:00, 2011-01-17 12:34:00, 201...
# ...          ...                                                ...
# 3915  18280.0000  [2011-03-07 09:52:00, 2011-03-07 09:52:00, 201...
# 3916  18281.0000  [2011-06-12 10:53:00, 2011-06-12 10:53:00, 201...
# 3917  18282.0000  [2011-08-05 13:35:00, 2011-08-05 13:35:00, 201...
# 3918  18283.0000  [2011-01-06 14:14:00, 2011-01-06 14:14:00, 201...
# 3919  18287.0000  [2011-05-22 10:39:00, 2011-05-22 10:39:00, 201...
#
#               first_order              last_2.           last_order  recency  \
# ...

# %%
df.loc[df['CustomerID']==12346.0000]
# Out:
#         InvoiceNo  StockCode                     Description   Quantity  \
# 61619 541431.0000 23166.0000  MEDIUM CERAMIC TOP STORAGE JAR 74215.0000
#
#               InvoiceDate  UnitPrice  CustomerID         Country    revenue  \
# 61619 2011-01-18 10:01:00     1.0400  12346.0000  United Kingdom 77183.6000
#
#       year_month
# 61619    2011-01

# %%
df_rfm[df_rfm["monetary"]<0]
# Out:
# Empty DataFrame
# Columns: [recency, frequency, monetary]
# Index: []

# %% [markdown]
# 2. Plot RFM distributions

# %%
sns.histplot(data=df_rfm, x='monetary', bins=50);

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
# RFM Table
df_rfm = df_uk_group[['CustomerID','recency', 'frequency', 'monetary']]
df_rfm
# Out:
#       CustomerID  recency  frequency   monetary
# 0     12346.0000      325          1 77183.6000
# 1     12747.0000        2         11  4196.0100
# 2     12748.0000        0        209 33719.7300
# 3     12749.0000        3          5  4090.8800
# 4     12820.0000        3          4   942.3400
# ...          ...      ...        ...        ...
# 3915  18280.0000      277          1   180.6000
# 3916  18281.0000      180          1    80.8200
# 3917  18282.0000        7          2   178.0500
# 3918  18283.0000        3         16  2094.8800
# 3919  18287.0000       42          3  1837.2800
#
# [3920 rows x 4 columns]

# %%
##Plot RFM distributions
plt.figure(figsize=(20,16))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.histplot(df_rfm['recency'], color="red", kde=True, stat="density", linewidth=0)
# Plot distribution of F
plt.subplot(3, 1, 2); sns.histplot(df_rfm['frequency'], color="blue", kde=True, stat="density", linewidth=0)
# Plot distribution of M
plt.subplot(3, 1, 3); sns.histplot(df_rfm['monetary'], color="green", kde=True, stat="density", linewidth=0)
# Show the plot
plt.show()

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
df_rfm['recency'].quantile(q=[0.25, 0.5, 0.75])  # df_rfm.quantile(q=[0.25, 0.50, 0.75])
# Out:
# 0.2500    17.0000
# 0.5000    50.0000
# 0.7500   142.0000
# Name: recency, dtype: float64

# %%
def recency_score(data):
    if data.recency <= 16.000:
        return 4
    elif data.recency <= 50.000:
        return 3
    elif data.recency <= 143.000:
        return 2
    else:
        return 1

# %%
df_rfm['frequency'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.2500   1.0000
# 0.5000   2.0000
# 0.7500   5.0000
# Name: frequency, dtype: float64

# %%
def frequency_score(data):
    if data.frequency <= 1.000:
        return 1
    elif data.frequency <= 3.000:
        return 2
    elif data.frequency <= 5.000:
        return 3
    else:
        return 4

# %%
df_rfm['monetary'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.2500    300.2800
# 0.5000    652.2800
# 0.7500   1576.5850
# Name: monetary, dtype: float64

# %%
def monetary_score(data):
    if data.monetary <= 281.030:
        return 1
    elif data.monetary <= 623.335:
        return 2
    elif data.monetary <= 1517.798:
        return 3
    else:
        return 4

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
df_rfm['recency_quantile'] = df_rfm.apply(recency_score, axis=1)
df_rfm['frequency_quantile'] = df_rfm.apply(frequency_score, axis=1)
df_rfm['monetary_quantile'] = df_rfm.apply(monetary_score, axis=1)
df_rfm.sample(5)
# Out:
#       CustomerID  recency  frequency  monetary  recency_quantile  \
# 1586  15069.0000      179          1 1109.5300                 1
# 2841  16777.0000       80          2  226.3500                 2
# 1865  15442.0000      248          1  594.0000                 1
# 3050  17068.0000       12         21 4552.1400                 4
# 3489  17690.0000       30         15 4757.9500                 3
#
#       frequency_quantile  monetary_quantile rfm_scores
# 1586                   1                  3        113
# 2841                   2                  1        221
# 1865                   1                  2        112
# 3050                   4                  4        444
# 3489                   4                  4        344

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
df_rfm['rfm_scores'] = (df_rfm.recency_quantile.apply(str) +
                        df_rfm.frequency_quantile.apply(str) +
                        df_rfm.monetary_quantile.apply(str))
df_rfm
# Out:
#       CustomerID  recency  frequency   monetary  recency_quantile  \
# 0     12346.0000      325          1 77183.6000                 1
# 1     12747.0000        2         11  4196.0100                 4
# 2     12748.0000        0        209 33719.7300                 4
# 3     12749.0000        3          5  4090.8800                 4
# 4     12820.0000        3          4   942.3400                 4
# ...          ...      ...        ...        ...               ...
# 3915  18280.0000      277          1   180.6000                 1
# 3916  18281.0000      180          1    80.8200                 1
# 3917  18282.0000        7          2   178.0500                 4
# 3918  18283.0000        3         16  2094.8800                 4
# 3919  18287.0000       42          3  1837.2800                 3
#
#       frequency_quantile  monetary_quantile rfm_scores
# 0                      1                  4        114
# 1                      4                  4        444
# ...

# %%
df_rfm[df_rfm['CustomerID']==13047.0000]
# Out:
#      CustomerID  recency  frequency  monetary  recency_quantile  \
# 163  13047.0000       31         10 3237.5400                 3
#
#      frequency_quantile  monetary_quantile rfm_scores
# 163                   4                  4        344

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
def segments1(data):
    if data['RFM_Level'] >= 10 :
        return 'Gold'
    elif (data['RFM_Level'] >= 6) and (data['RFM_Level'] < 10 ):
        return 'Silver'
    else:  
        return 'Bronze'

# %%
df_rfm['rfm_level'] = df_rfm.recency_quantile + df_rfm.frequency_quantile + df_rfm.monetary_quantile

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
df_rfm['rfm_level'].value_counts().sort_values(ascending=True)
# Out:
# 10    283
# 11    310
# 9     358
# 8     367
# 3     377
# 12    406
# 7     441
# 6     450
# 4     453
# 5     475
# Name: rfm_level, dtype: int64

# %%
def rfm_level_segment(data):
    if data.rfm_level == 12:
        return 'Best Customer'
    elif data.rfm_level > 10:
        return 'Loyal Customer'
    elif data.rfm_level > 8:
        return 'Big Spenders'
    elif data.rfm_level > 6:
        return 'Almost Lost'
    elif data.rfm_level > 4:
        return 'Lost Customers'
    else:
        return 'Lost Cheap Customers'

# %%
df_rfm['rfm_level_segment'] = df_rfm.apply(rfm_level_segment, axis=1)
df_rfm
# Out:
#       CustomerID  recency  frequency   monetary  recency_quantile  \
# 0     12346.0000      325          1 77183.6000                 1
# 1     12747.0000        2         11  4196.0100                 4
# 2     12748.0000        0        209 33719.7300                 4
# 3     12749.0000        3          5  4090.8800                 4
# 4     12820.0000        3          4   942.3400                 4
# ...          ...      ...        ...        ...               ...
# 3915  18280.0000      277          1   180.6000                 1
# 3916  18281.0000      180          1    80.8200                 1
# 3917  18282.0000        7          2   178.0500                 4
# 3918  18283.0000        3         16  2094.8800                 4
# 3919  18287.0000       42          3  1837.2800                 3
#
#       frequency_quantile  monetary_quantile rfm_scores  rfm_level  \
# 0                      1                  4        114          6
# ...

# %%
df_rfm.groupby('rfm_level_segment').agg({
    'recency': ['mean', 'median', 'min', 'max'],
    'frequency': ['mean', 'median', 'min', 'max'],
    'monetary': ['mean', 'median', 'min', 'max'],
    'rfm_level': ['mean', 'median', 'min', 'max', 'count']
}).round(1)
# Out:
#                       recency                   frequency                   \
#                          mean   median min  max      mean  median min  max
# rfm_level_segment
# Almost Lost           56.3000  40.0000   0  358    2.6000  2.0000   1    7
# Best Customer          6.2000   5.0000   0   16   16.0000 11.0000   6  209
# Big Spenders          37.9000  26.0000   0  372    4.8000  4.0000   1   39
# Lost Cheap Customers 222.9000 233.0000  51  373    1.1000  1.0000   1    3
# Lost Customers       103.8000  74.0000   1  372    1.6000  1.0000   1    6
# Loyal Customer        20.4000  19.0000   0   50    8.3000  7.0000   4   63
#
#                       monetary                                 rfm_level  \
#                           mean    median       min         max      mean
# rfm_level_segment
# Almost Lost           975.2000  712.8000   36.6000  44534.3000    7.5000
# Best Customer        8516.6000 3993.8000 1528.1000 259657.3000   12.0000
# ...

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
plt.figure(figsize=(20, 5))
df_rfm = df_rfm.sort_values('rfm_level_segment')

plt.subplot(1, 3, 1)
sns.boxplot(df_rfm['rfm_level_segment'], df_rfm['recency'])
plt.xticks(rotation=90)

plt.subplot(1, 3, 2)
sns.boxplot(df_rfm['rfm_level_segment'], df_rfm['frequency'])
plt.xticks(rotation=90)

plt.subplot(1, 3, 3)
sns.boxplot(df_rfm['rfm_level_segment'], df_rfm['monetary'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales) we can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
df_rfm.rfm_level_segment.value_counts(ascending=False)
# Out:
# Lost Customers          926
# Lost Cheap Customers    833
# Almost Lost             805
# Big Spenders            642
# Best Customer           404
# Loyal Customer          310
# Name: rfm_level_segment, dtype: int64

# %%
df_rfm.rfm_level_segment.value_counts(ascending=False).plot.bar()

# %%
labels = df_rfm.rfm_level_segment.value_counts().index

plt.figure(figsize=(10, 8))
plt.pie(df_rfm.rfm_level_segment.value_counts(ascending=False),
        labels=labels,
        autopct='%.0f%%');

# %%
plt.figure(figsize=(30,25))
sns.pairplot(df_rfm[['recency', 'frequency', 'monetary','rfm_level_segment']], hue = 'rfm_level_segment');

# %%
# pip install squarify

# %%
df_plot2 = pd.DataFrame(df_rfm["rfm_level_segment"].value_counts(dropna=False).sort_values(ascending=False)).reset_index().rename(columns={'index':'Segments', 'rfm_level_segment':'Customers'})
df_plot2
# Out:
#                Segments  Customers
# 0        Lost Customers        925
# 1  Lost Cheap Customers        830
# 2           Almost Lost        808
# 3          Big Spenders        641
# 4         Best Customer        406
# 5        Loyal Customer        310

# %%
# MATPLOTLIB
y = df_plot2.Customers.values
x = df_plot2.Segments.values

fig, ax = plt.subplots(figsize = (16,9), dpi=72)
ax.bar(x,y,width=0.4)

plt.title("RFM PLOT WITH SEGMENTS2")
plt.xlabel("SEGMENTS2");
plt.ylabel("CUSTOMERS");
plt.xticks(rotation = 45)

for index,value in enumerate(y):
    plt.text(x=index , y =value , s=str(value) , ha="center", va="bottom", color = 'gray', fontweight = 'bold', fontdict=dict(fontsize=20))
plt.show()

# %%
# MATPLOTLIB SQUARIFY

import squarify

fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(10, 10)
squarify.plot(sizes=list(df_plot2['Customers'].values), 
              label=list(df_plot2['Segments'].values), alpha=0.8,
              text_kwargs={'fontsize':12})
plt.title("RFM Segments",fontsize=22,fontweight="bold")
plt.axis('off')
plt.show()

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into 6 different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
rfm = df_rfm.loc[:, ["recency", "frequency", "monetary"]]
rfm.head()
# Out:
#       recency  frequency  monetary
# 1959      103          5 1375.7100
# 373        82          3 3536.8200
# 3728       35          1  668.1100
# 3393       94          4  854.9500
# 146        64          2  689.9000

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
sns.heatmap(rfm.corr(),annot=True);

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(rfm);

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. You can use the logarithm method to normalize the values in a column.

# %%
rfm_log = rfm.apply(np.log1p)
rfm_log.describe()
# Out:
#         recency  frequency  monetary
# count 3920.0000  3920.0000 3920.0000
# mean     3.7988     1.3463    6.5462
# std      1.3823     0.6823    1.2437
# min      0.0000     0.6931    1.5581
# 25%      2.8904     0.6931    5.7080
# 50%      3.9318     1.0986    6.4820
# 75%      4.9628     1.7918    7.3637
# max      5.9243     5.3471   12.4671

# %% [markdown]
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(rfm_log)

rfm_normalized = scaler.transform(rfm_log)

rfm_normalized = pd.DataFrame(data=rfm_normalized,
                              index=rfm.index,
                              columns=rfm.columns)

# %%
rfm_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3920 entries, 1959 to 1412
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   recency    3920 non-null   float64
#  1   frequency  3920 non-null   float64
#  2   monetary   3920 non-null   float64
# dtypes: float64(3)
# memory usage: 122.5 KB

# %%
f,ax = plt.subplots(figsize=(10, 6))
plt.subplot(3, 1, 1); sns.distplot(rfm_normalized.recency, label = 'recency')
plt.subplot(3, 1, 2); sns.distplot(rfm_normalized.frequency, label = 'frequency')
plt.subplot(3, 1, 3); sns.distplot(rfm_normalized.monetary, label = 'monetary')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
from sklearn.cluster import KMeans

ssd = []
for n in range(2, 11):
    kmeans = KMeans(n_clusters=n, random_state=42)
    kmeans.fit(rfm_normalized)
    ssd.append(kmeans.inertia_)
plt.figure(figsize=(10, 6))
plt.plot(range(2, 11), ssd, "bo-")
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('ssd')
plt.show()

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
from sklearn.metrics import silhouette_score

range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:

    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_normalized)

    cluster_labels = kmeans.labels_

    silhouette_avg = silhouette_score(rfm_normalized, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(
        num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.4363193120781418
# For n_clusters=3, the silhouette score is 0.34594309355974895
# For n_clusters=4, the silhouette score is 0.336108683531537
# For n_clusters=5, the silhouette score is 0.3185094476502106
# For n_clusters=6, the silhouette score is 0.31368113348709004
# For n_clusters=7, the silhouette score is 0.31013897806292623
# For n_clusters=8, the silhouette score is 0.3045374507525724

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(rfm_normalized)
y_kmeans = kmeans.predict(rfm_normalized)

labels = kmeans.labels_
rfm_normalized['labels'] = labels
rfm_normalized['cluster_Kmeans'] = kmeans.fit_predict(rfm_normalized)
rfm_normalized
# Out:
#       recency  frequency  monetary  labels  cluster_Kmeans
# 1959   0.6118     0.6529    0.5479       0               2
# 373    0.4486     0.0586    1.3069       0               2
# 3728  -0.1557    -0.9575   -0.0323       1               0
# 3393   0.5463     0.3857    0.1657       0               2
# 146    0.2718    -0.3631   -0.0066       0               2
# ...       ...        ...       ...     ...             ...
# 11    -1.9536     0.8789    0.3065       2               1
# 2413  -0.2409     2.0907    1.8455       2               1
# 9     -1.9536     1.0746    0.6037       2               1
# 748   -0.5120     1.8949    1.2314       2               1
# 1412  -0.0616     1.6690    0.8832       2               1
#
# [3920 rows x 5 columns]

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
plt.figure(figsize=(12, 8))
plt.scatter(rfm_normalized.iloc[:, 0],
            rfm_normalized.iloc[:, 1],
            c=y_kmeans,
            s=50)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.9)

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
f, (ax1, ax2) = plt.subplots(
    1, 2, sharey=True,
    figsize=(14, 6))  # sharey=True and y-axis labels are used in common.
ax1.set_title('recency-frequency')
ax1.set_xlabel('recency')
ax1.set_ylabel('frequency')
ax1.scatter(rfm_normalized["recency"],
            rfm_normalized["frequency"],
            c=kmeans.labels_,
            cmap="viridis")
ax1.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            s=300,
            alpha=1,
            label='Centroids')

ax2.set_title("frequency-monetary")
ax2.set_xlabel('frequency')
ax2.set_ylabel('monetary')
ax2.scatter(rfm_normalized["frequency"],
            rfm_normalized["monetary"],
            c=kmeans.labels_,
            cmap="viridis")
ax2.scatter(kmeans.cluster_centers_[:, 1],
            kmeans.cluster_centers_[:, 2],
            s=300,
            alpha=1,
            label='Centroids')

# %% [markdown]
# ### iv. Assign the Label

# %%
cluster_labels = kmeans.labels_

rfm_k3 = df_rfm.assign(Cluster=cluster_labels)

rfm_normalized['result'] = rfm_normalized['labels'].apply(
    lambda x: 'Best Customers'
    if x == 0 else ('Almost Lost' if x == 1 else 'Attention Customers'))
rfm_normalized.sample(5)
# Out:
#       recency  frequency  monetary  labels  cluster_Kmeans  \
# 1040  -1.2439     1.4017    1.5679       2               1
# 1153  -1.4521     1.4017    1.1829       2               1
# 2573   0.1376    -0.9575   -1.3026       1               2
# 2800   0.0372     0.3857    0.3337       0               0
# 3498  -0.6986     0.3857    1.0428       0               0
#
#                    result
# 1040  Attention Customers
# 1153  Attention Customers
# 2573          Almost Lost
# 2800       Best Customers
# 3498       Best Customers

# %%
plt.figure(figsize = (15,5))

plt.subplot(1,3,1)
sns.boxplot(rfm_normalized['labels'], rfm_normalized.recency)
            
plt.subplot(1,3,2)
sns.boxplot(rfm_normalized['labels'], rfm_normalized.frequency)
            
plt.subplot(1,3,3)
sns.boxplot(rfm_normalized['labels'], rfm_normalized.monetary);

# %% [markdown]
# **Conclusion Example :**
#
# - Cluster 0 : The first cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)
#
# - Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
# - Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
import datetime as dt 

def take_months(x) :
    return dt.datetime(x.year, x.month, 1)

df_cohort = df

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %%
df_cohort['invoice_month'] = df_cohort['InvoiceDate'].apply(take_months)
df_cohort.invoice_month.tail(50)
# Out:
# 541859   2011-12-01
# 541860   2011-12-01
# 541861   2011-12-01
# 541862   2011-12-01
# 541863   2011-12-01
# 541864   2011-12-01
# 541865   2011-12-01
# 541866   2011-12-01
# 541867   2011-12-01
# 541868   2011-12-01
# 541869   2011-12-01
# 541870   2011-12-01
# 541871   2011-12-01
# 541872   2011-12-01
# 541873   2011-12-01
# 541874   2011-12-01
# 541875   2011-12-01
# 541876   2011-12-01
# 541877   2011-12-01
# 541878   2011-12-01
# 541879   2011-12-01
# 541880   2011-12-01
# 541881   2011-12-01
# 541882   2011-12-01
# 541883   2011-12-01
# 541884   2011-12-01
# 541885   2011-12-01
# 541886   2011-12-01
# 541887   2011-12-01
# 541888   2011-12-01
# 541889   2011-12-01
# 541890   2011-12-01
# 541891   2011-12-01
# 541892   2011-12-01
# 541893   2011-12-01
# 541894   2011-12-01
# 541895   2011-12-01
# 541896   2011-12-01
# 541897   2011-12-01
# 541898   2011-12-01
# 541899   2011-12-01
# 541900   2011-12-01
# 541901   2011-12-01
# 541902   2011-12-01
# 541903   2011-12-01
# ...

# %%
df_cohort['cohort_month'] = df_cohort.groupby('CustomerID')['invoice_month'].transform('min')
df_cohort.cohort_month.tail(50)
# Out:
# 541859   2010-12-01
# 541860   2010-12-01
# 541861   2010-12-01
# 541862   2010-12-01
# 541863   2010-12-01
# 541864   2010-12-01
# 541865   2010-12-01
# 541866   2010-12-01
# 541867   2010-12-01
# 541868   2010-12-01
# 541869   2011-05-01
# 541870   2011-05-01
# 541871   2011-05-01
# 541872   2011-05-01
# 541873   2011-05-01
# 541874   2011-05-01
# 541875   2011-05-01
# 541876   2011-05-01
# 541877   2011-05-01
# 541878   2011-05-01
# 541879   2011-05-01
# 541880   2011-05-01
# 541881   2011-05-01
# 541882   2011-05-01
# 541883   2011-05-01
# 541884   2011-05-01
# 541885   2011-05-01
# 541886   2011-05-01
# 541887   2011-05-01
# 541888   2011-05-01
# 541889   2011-05-01
# 541890   2010-12-01
# 541891   2010-12-01
# 541892   2010-12-01
# 541893   2010-12-01
# 541894   2011-08-01
# 541895   2011-08-01
# 541896   2011-08-01
# 541897   2011-08-01
# 541898   2011-08-01
# 541899   2011-08-01
# 541900   2011-08-01
# 541901   2011-08-01
# 541902   2011-08-01
# 541903   2011-08-01
# ...

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %%
def get_date_int(df_x, column):
    year = df_x[column].dt.year
    month = df_x[column].dt.month
    day = df_x[column].dt.day
    return year, month, day

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 seperate series for each of the two columns

# %%
invoice_year, invoice_month, invoice_day =  get_date_int(df_cohort, 'invoice_month')
cohort_year, cohort_month, cohort_day = get_date_int(df_cohort, 'cohort_month')

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %%
year_diff = invoice_year - cohort_year
month_diff = invoice_month - cohort_month

# %%
df_cohort['cohort_index'] = year_diff * 12 + month_diff + 1
df_cohort
# Out:
#          InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365.0000     85123A   WHITE HANGING HEART T-LIGHT HOLDER    6.0000
# 1      536365.0000 71053.0000                  WHITE METAL LANTERN    6.0000
# 2      536365.0000     84406B       CREAM CUPID HEARTS COAT HANGER    8.0000
# 3      536365.0000     84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6.0000
# 4      536365.0000     84029E       RED WOOLLY HOTTIE WHITE HEART.    6.0000
# ...            ...        ...                                  ...       ...
# 541904 581587.0000 22613.0000          PACK OF 20 SPACEBOY NAPKINS   12.0000
# 541905 581587.0000 22899.0000         CHILDREN'S APRON DOLLY GIRL     6.0000
# 541906 581587.0000 23254.0000        CHILDRENS CUTLERY DOLLY GIRL     4.0000
# 541907 581587.0000 23255.0000      CHILDRENS CUTLERY CIRCUS PARADE    4.0000
# 541908 581587.0000 22138.0000        BAKING SET 9 PIECE RETROSPOT     3.0000
#
# ...

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort1 = df_cohort.groupby(['cohort_month', 'cohort_index'])['CustomerID'].nunique().reset_index()
cohort1
# Out:
#    cohort_month  cohort_index  CustomerID
# 0    2010-12-01        1.0000         885
# 1    2010-12-01        2.0000         324
# 2    2010-12-01        3.0000         286
# 3    2010-12-01        4.0000         340
# 4    2010-12-01        5.0000         321
# ..          ...           ...         ...
# 86   2011-10-01        2.0000          86
# 87   2011-10-01        3.0000          41
# 88   2011-11-01        1.0000         323
# 89   2011-11-01        2.0000          36
# 90   2011-12-01        1.0000          41
#
# [91 rows x 3 columns]

# %%
pivot_cohort1 = cohort1.reset_index().pivot(index = 'cohort_month', columns = 'cohort_index', values = 'CustomerID')
pivot_cohort1
# Out:
# cohort_index  1.0000   2.0000   3.0000   4.0000   5.0000   6.0000   7.0000   \
# cohort_month
# 2010-12-01   885.0000 324.0000 286.0000 340.0000 321.0000 352.0000 321.0000
# 2011-01-01   417.0000  92.0000 111.0000  96.0000 134.0000 120.0000 103.0000
# 2011-02-01   380.0000  71.0000  71.0000 108.0000 103.0000  94.0000  96.0000
# 2011-03-01   452.0000  68.0000 114.0000  90.0000 101.0000  76.0000 121.0000
# 2011-04-01   300.0000  64.0000  61.0000  63.0000  59.0000  68.0000  65.0000
# 2011-05-01   284.0000  54.0000  49.0000  49.0000  59.0000  66.0000  75.0000
# 2011-06-01   242.0000  42.0000  38.0000  64.0000  56.0000  81.0000  23.0000
# 2011-07-01   188.0000  34.0000  39.0000  42.0000  51.0000  21.0000      NaN
# 2011-08-01   169.0000  35.0000  42.0000  41.0000  21.0000      NaN      NaN
# 2011-09-01   299.0000  70.0000  90.0000  34.0000      NaN      NaN      NaN
# 2011-10-01   358.0000  86.0000  41.0000      NaN      NaN      NaN      NaN
# ...

# %%
# Retention Rate :
cohort_size = pivot_cohort1.iloc[:,0]
cohort_size
# Out:
# cohort_month
# 2010-12-01   885.0000
# 2011-01-01   417.0000
# 2011-02-01   380.0000
# 2011-03-01   452.0000
# 2011-04-01   300.0000
# 2011-05-01   284.0000
# 2011-06-01   242.0000
# 2011-07-01   188.0000
# 2011-08-01   169.0000
# 2011-09-01   299.0000
# 2011-10-01   358.0000
# 2011-11-01   323.0000
# 2011-12-01    41.0000
# Name: 1.0, dtype: float64

# %%
retention = pivot_cohort1.divide(cohort_size, axis = 0)
retention.index = retention.index.strftime('%m-%Y')
retention
# Out:
# cohort_index  1.0000   2.0000   3.0000   4.0000   5.0000   6.0000   7.0000   \
# cohort_month
# 12-2010        1.0000   0.3661   0.3232   0.3842   0.3627   0.3977   0.3627
# 01-2011        1.0000   0.2206   0.2662   0.2302   0.3213   0.2878   0.2470
# 02-2011        1.0000   0.1868   0.1868   0.2842   0.2711   0.2474   0.2526
# 03-2011        1.0000   0.1504   0.2522   0.1991   0.2235   0.1681   0.2677
# 04-2011        1.0000   0.2133   0.2033   0.2100   0.1967   0.2267   0.2167
# 05-2011        1.0000   0.1901   0.1725   0.1725   0.2077   0.2324   0.2641
# 06-2011        1.0000   0.1736   0.1570   0.2645   0.2314   0.3347   0.0950
# 07-2011        1.0000   0.1809   0.2074   0.2234   0.2713   0.1117      NaN
# 08-2011        1.0000   0.2071   0.2485   0.2426   0.1243      NaN      NaN
# 09-2011        1.0000   0.2341   0.3010   0.1137      NaN      NaN      NaN
# 10-2011        1.0000   0.2402   0.1145      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(16,9))
plt.title('Retention Rate')
sns.heatmap(data = retention, annot = True, fmt = '.0%',cmap='Blues');

# %% [markdown]
# - Number of unique customers are calculated in each group of cohort date
# - 13 cohorts for each month and 13 cohort indexes.
#
# - Sample:
# 	* 06-2011 cohort_month in 6th Cohort Index,
# 	* 33% of cohorts that signed in Jun 2011 were active 6 months later.

# %%
plt.figure(figsize=(15, 6))
# retention[list(range(1,14))].plot(figsize=(10,5))
retention.loc[['12-2010', '01-2011','02-2011', '04-2011' ], :].T.plot(
    figsize=(10, 5))
# retention.iloc[:,:].T.plot(figsize=(10,5))
plt.title('Cohorts: Retention')
plt.xlim(1, 12)
plt.ylim(0, 0.6)
plt.xlabel('Cohort Period')
plt.ylabel('% of Cohort Purchasing')
# Out:
# Text(0, 0.5, '% of Cohort Purchasing')

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort2 = df_cohort.groupby(['cohort_month', 'cohort_index'])['Quantity'].mean().reset_index()
cohort2
# Out:
#    cohort_month  cohort_index  Quantity
# 0    2010-12-01        1.0000   11.9381
# 1    2010-12-01        2.0000   15.5731
# 2    2010-12-01        3.0000   15.5930
# 3    2010-12-01        4.0000   15.7606
# 4    2010-12-01        5.0000   13.5051
# ..          ...           ...       ...
# 86   2011-10-01        2.0000    7.1549
# 87   2011-10-01        3.0000    8.3593
# 88   2011-11-01        1.0000    7.7185
# 89   2011-11-01        2.0000    9.8000
# 90   2011-12-01        1.0000   14.8760
#
# [91 rows x 3 columns]

# %%
second_pivot = cohort2.pivot(index='cohort_month', columns='cohort_index', values='Quantity').round(1)
second_pivot
# Out:
# cohort_index  1.0000   2.0000   3.0000   4.0000   5.0000   6.0000   7.0000   \
# cohort_month
# 2010-12-01    11.9000  15.6000  15.6000  15.8000  13.5000  14.8000  16.0000
# 2011-01-01    17.2000  13.3000  12.6000  15.1000  12.8000  15.3000  14.9000
# 2011-02-01    11.1000  13.5000  19.0000  12.0000  12.3000  12.3000  13.5000
# 2011-03-01     9.9000  11.7000  13.3000  10.1000  14.3000  13.0000  13.4000
# 2011-04-01    10.0000  10.4000   9.8000  11.8000  11.8000   8.6000   9.9000
# 2011-05-01    11.3000   9.6000  14.1000  12.8000  11.1000   8.7000  10.6000
# 2011-06-01    10.6000  14.5000  10.8000  13.5000  10.6000   9.8000   9.4000
# 2011-07-01     9.8000  13.8000   7.3000   8.1000   6.1000   7.1000      NaN
# 2011-08-01    10.0000   6.2000   5.4000   6.2000   7.1000      NaN      NaN
# 2011-09-01    12.1000   6.2000   8.0000   8.9000      NaN      NaN      NaN
# 2011-10-01     8.9000   7.2000   8.4000      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(16,9))
plt.title('Average Quantity')
sns.heatmap(data = second_pivot, annot = True, fmt = 'g',cmap='Blues');

# %%
plt.figure(figsize=(16,9))
plt.title('Average Quantity %')
sns.heatmap(data = second_pivot, annot = True, fmt = '.0%',cmap='Blues');

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort3 = df_cohort.groupby(['cohort_month', 'cohort_index'])['revenue'].mean().reset_index()
cohort3.head()
# Out:
#   cohort_month  cohort_index  revenue
# 0   2010-12-01        1.0000  21.8952
# 1   2010-12-01        2.0000  27.1140
# 2   2010-12-01        3.0000  26.6430
# 3   2010-12-01        4.0000  26.9033
# 4   2010-12-01        5.0000  21.0123

# %%
third_pivot = cohort3.pivot(index='cohort_month', columns='cohort_index', values='revenue').round(2)
third_pivot.head()
# Out:
# cohort_index  1.0000   2.0000   3.0000   4.0000   5.0000   6.0000   7.0000   \
# cohort_month
# 2010-12-01    21.9000  27.1100  26.6400  26.9000  21.0100  27.9200  28.0700
# 2011-01-01    26.5600  24.8400  20.8200  30.9400  22.3700  26.0800  25.1000
# 2011-02-01    17.7100  20.5700  21.2700  19.2600  17.6200  16.8900  22.1100
# 2011-03-01    17.4600  21.0400  22.6400  17.9600  21.1300  18.9200  21.9200
# 2011-04-01    16.8600  20.9600  19.4800  18.6900  19.2900  14.8200  15.0600
#
# cohort_index  8.0000   9.0000   10.0000  11.0000  12.0000  13.0000
# cohort_month
# 2010-12-01    27.1900  29.0700  33.2200  33.6700  23.2700  25.6100
# 2011-01-01    25.2400  18.9900  22.1100  19.3700  19.3000      NaN
# 2011-02-01    22.7900  18.5800  22.0000  23.5000      NaN      NaN
# 2011-03-01    19.8400  16.6000  12.9200      NaN      NaN      NaN
# 2011-04-01    15.6600  12.1400      NaN      NaN      NaN      NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize = (16, 9))
plt.title('Average unitprice for each cohort')
sns.heatmap(data=third_pivot ,annot = True, vmin = 0.0, vmax =100,cmap='Blues')
plt.show()

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
